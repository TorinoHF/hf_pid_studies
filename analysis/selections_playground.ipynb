# %%
import uproot
import matplotlib.pyplot as plt

# %% [markdown]
# # Cascades

# %%
with uproot.open("/home/fchinu/Run3/pid_studies/dataset/LHC22o_pass7/Train300244/AO2D.root") as f:
    df = f["DF_2261906081476736/O2pidcascades"].arrays(library="pd")

# %%
df.columns
# Out:
# Index(['fMassOmega', 'fPt', 'fBachPt', 'fV0cosPA', 'fMassXi', 'fCascCosPA',
#        'fDCAV0daughters', 'fDCAv0topv', 'fNSigmaTpcBachKa', 'fNSigmaTofBachKa',
#        'fOccupancyFt0c', 'fOccupancyIts', 'fCentralityFT0C', 'fCentralityFT0M',
#        'fCandFlag'],
#       dtype='object')

# %%
df["fDCAV0daughters"].hist(bins=100, range=(0, 1), log=True)
# Out:
# <Axes: >

# %%
df["fCascCosPA"].hist(bins=100, range=(0.95, 1), log=True)
# Out:
# <Axes: >

# %%
df["fMassXi"].hist(bins=100, range=(1.3, 1.34))
# Out:
# <Axes: >

# %%
df["fV0cosPA"].hist(bins=100, range=(0.95, 1), log=True)
# Out:
# <Axes: >

# %%
df["fDCAv0topv"].hist(bins=100, range=(0, 1))
# Out:
# <Axes: >

# %%
df.query("fDCAv0topv > 0.2 and fDCAV0daughters < 0.1 and fV0cosPA>0.99 and fCascCosPA > 0.9995 and (fMassXi < 1.3 or fMassXi > 1.34)")["fMassOmega"].hist(bins=100, range=(1.6, 1.8))
# Out:
# <Axes: >

# %%
df["fMassOmega"].hist(bins=100, range=(1.6, 1.8))
# Out:
# <Axes: >

# %%
df.query("fDCAv0topv > 0.2 and fDCAV0daughters < 0.1 and fV0cosPA>0.99 and fCascCosPA > 0.9995 and (fMassXi < 1.3 or fMassXi > 1.34)")["fNSigmaTpcBachKa"].hist(bins=100, range=(-5, 5))
# Out:
# <Axes: >

# %%
df.query("fDCAv0topv > 0.2 and fDCAV0daughters < 0.1 and fV0cosPA>0.99 and fCascCosPA > 0.9995 and (fMassXi < 1.3 or fMassXi > 1.34)")["fNSigmaTofBachKa"].hist(bins=100, range=(-5, 5))
# Out:
# <Axes: >

# %% [markdown]
# # K0s

# %%
with uproot.open("/home/fchinu/Run3/pid_studies/datasets/LHC22o_pass7/Train300243/Tree_LHC22o_pass7_K0s_Lambda.root") as f:
    df = f["DF_2261906079905024/O2pidv0s"].arrays(library="pd")

# %%
df.columns
# Out:
# Index(['fMassK0', 'fMassLambda', 'fMassAntiLambda', 'fPt', 'fPtPos', 'fPtNeg',
#        'fRadius', 'fCpa', 'fNSigmaTpcPosPi', 'fNSigmaTpcNegPi',
#        'fNSigmaTpcPosPr', 'fNSigmaTpcNegPr', 'fNSigmaTofPosPi',
#        'fNSigmaTofNegPi', 'fNSigmaTofPosPr', 'fNSigmaTofNegPr', 'fAlphaArm',
#        'fQtArm', 'fOccupancyFt0c', 'fOccupancyIts', 'fCentralityFT0C',
#        'fCentralityFT0M', 'fCandFlag'],
#       dtype='object')

# %%
plt.hist2d(df["fAlphaArm"], df["fQtArm"], bins=(100, 100), range=((-1.5, 1.5), (0, 0.3)))
plt.show()

# %%
df_sel = df.query("(fMassLambda < 1.11 or fMassLambda > 1.12) and (fMassAntiLambda < 1.11 or fMassAntiLambda > 1.12) and fRadius >0.5 and fCpa > 0.9999 and fQtArm > 0.18")

# %%
df_sel["fAlphaArm"].hist(bins=100, range=(-0.5, 0.5))
# Out:
# <Axes: >

# %%
df_sel["fQtArm"].hist(bins=100, range=(0.15, 0.25))
# Out:
# <Axes: >

# %%
df_sel["fCpa"].hist(bins=100, range=(0.95, 1))
# Out:
# <Axes: >

# %%
df_sel["fRadius"].hist(bins=100, range=(0, 20))
# Out:
# <Axes: >

# %%
df_sel["fMassAntiLambda"].hist(bins=100, range=(1.1, 1.13))
# Out:
# <Axes: >

# %%
df_sel["fMassK0"].hist(bins=100, range=(0.48, 0.52))
# Out:
# <Axes: >

# %%
df["fMassK0"].hist(bins=100, range=(0.48, 0.52))
# Out:
# <Axes: >
