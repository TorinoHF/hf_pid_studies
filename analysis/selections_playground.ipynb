# %%
import uproot
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Cascades

# %%
# with uproot.open("/home/fchinu/Run3/pid_studies/datasets/LHC22o_pass7/Train306390/Tree_LHC22o_pass7_Casc.root") as f:
#     df = f["DF_2261906082599168/O2pidcascades"].arrays(library="pd")

# %%
df = pd.read_parquet("/data/shared/hf_pid_studies_pbpb/v0s/Data/Train306573/LHC23zzh_pass4_small_v0s.parquet", engine="pyarrow")

# %%
df.columns
# Out:
# Index(['fMassK0', 'fMassLambda', 'fMassAntiLambda', 'fPt', 'fPtPos', 'fPtNeg',
#        'fTpcInnerParPos', 'fTpcInnerParNeg', 'fRadius', 'fCpa',
#        'fDcaV0Daughters', 'fDcaV0ToPv', 'fNSigmaTpcPosPi', 'fNSigmaTpcNegPi',
#        'fNSigmaTpcPosPr', 'fNSigmaTpcNegPr', 'fNSigmaTofPosPi',
#        'fNSigmaTofNegPi', 'fNSigmaTofPosPr', 'fNSigmaTofNegPr', 'fAlphaArm',
#        'fQtArm', 'fOccupancyFt0c', 'fOccupancyIts', 'fCentralityFT0C',
#        'fCentralityFT0M', 'fCandFlag'],
#       dtype='object')

# %%
df["fMassK0"].hist(bins=100, range=(0.4, 0.6), log=True)
# df["fDcaV0Daughters"].hist(bins=100, range=(0, 1), log=True)
# Out:
# <Axes: >

# %%
df["fPtPos"].hist(bins=100, range=(0, 20), log=True)
# df["fDcaV0Daughters"].hist(bins=100, range=(0, 1), log=True)
# Out:
# <Axes: >

# %%
df.query("fPt < 12")["fPtPos"].hist(bins=100, range=(0, 20), log=True)
# df["fMassK0"].hist(bins=100, range=(0.4, 0.6), log=True)
# Out:
# <Axes: >

# %%
# df.query("20 < fCentralityFT0C < 40 and 0 < fOccupancyFt0c < 20000")["fPtPos"].hist(bins=100, range=(0, 10), log=True)
df.query("20 < fCentralityFT0C < 40 and 0 < fOccupancyFt0c < 20000")["fPt"].hist(bins=100, range=(0, 10), log=True)
# Out:
# <Axes: >

# %%
df.query("20 < fCentralityFT0C < 40 and 0 < fOccupancyFt0c < 20000 and 2.0 < fPtNeg < 5.0")["fMassK0"].hist(bins=100, range=(0.4, 0.6))
# df.query("0 < fCentralityFT0C < 100 and 0 < fOccupancyFt0c < 999999999 and 3.0 < fPtNeg < 5.0")["fMassK0"].hist(bins=100, range=(0.4, 0.6))
# df.query("20 < fCentralityFT0C < 40 and 0 < fOccupancyFt0c < 20000 and 1.6 < fPtNeg < 2.0")["fMassK0"].hist(bins=100, range=(0.4, 0.6))
# Out:
# <Axes: >

# %%
df["fV0cosPA"].hist(bins=100, range=(0.95, 1), log=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/virtenvpy/phys/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fV0cosPA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df["fV0cosPA"].hist(bins=100, range=(0.95, 1), log=True)
#
# ...

# %%
df["fMLambda"].hist(bins=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/virtenvpy/phys/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fMLambda'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df["fMLambda"].hist(bins=100)
#
# ...

# %%
df["fMassXi"].hist(bins=100, range=(1.3, 1.34))
# Out:
# <Axes: >

# %%
df["fV0cosPA"].hist(bins=100, range=(0.95, 1), log=True)
# Out:
# <Axes: >

# %%
df["fDcaV0ToPv"].hist(bins=100, range=(0, 1))
# Out:
# <Axes: >

# %%
df.query("fDcaV0ToPv > 0.2 and fDcaV0Daughters < 0.1 and fV0cosPA>0.99 and fCascCosPa > 0.9995 and (fMassXi < 1.3 or fMassXi > 1.34)")["fMassOmega"].hist(bins=100, range=(1.65, 1.7))
# Out:
# <Axes: >

# %%
df["fMassOmega"].hist(bins=100, range=(1.65, 1.7))
# Out:
# <Axes: >

# %% [markdown]
# # K0s

# %%
with uproot.open("/home/fchinu/Run3/pid_studies/datasets/LHC22o_pass7/Train306507/Tree_LHC22o_pass7_K0s_Lambda.root") as f:
    df = f["DF_2261906078589184/O2pidv0s"].arrays(library="pd")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 with uproot.open("/home/fchinu/Run3/pid_studies/datasets/LHC22o_pass7/Train306507/Tree_LHC22o_pass7_K0s_Lambda.root") as f:
# ----> 2     df = f["DF_2261906078589184/O2pidv0s"].arrays(library="pd")
#
# File ~/.virtualenv/ml311/lib/python3.11/site-packages/uproot/behaviors/TBranch.py:826, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     823                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     825 interp_options = {"ak_add_doc": ak_add_doc}
# --> 826 _ranges_or_baskets_to_arrays(
#     827     self,
#     828     ranges_or_baskets,
#     829     branchid_interpretation,
# ...

# %%
df.columns
# Out:
# Index(['fMassK0', 'fMassLambda', 'fMassAntiLambda', 'fPt', 'fPtPos', 'fPtNeg',
#        'fRadius', 'fCpa', 'fNSigmaTpcPosPi', 'fNSigmaTpcNegPi',
#        'fNSigmaTpcPosPr', 'fNSigmaTpcNegPr', 'fNSigmaTofPosPi',
#        'fNSigmaTofNegPi', 'fNSigmaTofPosPr', 'fNSigmaTofNegPr', 'fAlphaArm',
#        'fQtArm', 'fOccupancyFt0c', 'fOccupancyIts', 'fCentralityFT0C',
#        'fCentralityFT0M', 'fCandFlag'],
#       dtype='object')

# %%
df["fOccupancyFt0c"].hist(bins=100, range=(0, 20000))
# Out:
# <Axes: >
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.hist2d(df["fAlphaArm"], df["fQtArm"], bins=(100, 100), range=((-1.5, 1.5), (0, 0.3)))
plt.show()

# %%
df_sel = df.query("(fMassLambda < 1.11 or fMassLambda > 1.12) and (fMassAntiLambda < 1.11 or fMassAntiLambda > 1.12) and fRadius >0.5 and fCpa > 0.9999 and fQtArm > 0.18")

# %%
df_sel["fAlphaArm"].hist(bins=100, range=(-0.5, 0.5))
# Out:
# <Axes: >

# %%
df_sel["fQtArm"].hist(bins=100, range=(0.15, 0.25))
# Out:
# <Axes: >

# %%
df_sel["fCpa"].hist(bins=100, range=(0.95, 1))
# Out:
# <Axes: >

# %%
df_sel["fRadius"].hist(bins=100, range=(0, 20))
# Out:
# <Axes: >

# %%
df_sel["fMassAntiLambda"].hist(bins=100, range=(1.1, 1.13))
# Out:
# <Axes: >

# %%
df_sel["fMassK0"].hist(bins=100, range=(0.48, 0.52))
# Out:
# <Axes: >

# %%
df["fMassK0"].hist(bins=100, range=(0.48, 0.52))
# Out:
# <Axes: >
